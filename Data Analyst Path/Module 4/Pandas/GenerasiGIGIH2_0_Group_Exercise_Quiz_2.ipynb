# %% [markdown]
# List Of Question:
# # **MODULE 4 DAY 2 QUIZ**
#
# # Group 1 & 2
# Which country has the lowest death caused by nutrition in 2019? Indonesia
#
# Which country has the highest rate of diabetes prevalence in 2021? Rusia
#
# How much is the working age population of Mali in 2020?
#
# How many Indonesian adults (age 15+) are living with HIV in 2020?
#
# Which country has the lowest rate of literacy in 2020? Mexico
#
# # Group 3 & 4
# Which country has the highest total fertility rate in 2019?
#
# Which country has the lowest rate of diabetes prevalence in 2021?
#
# Which country has the lowest prevalence of overweight adults in 2016?
#
# How many Indonesian children (age <15) are living with HIV in 2020?
#
# Which country has the highest probability of dying per 1000 among adolescents ages 5-9 years in 2020?
#
# # Group 5 & 6
# Which country has the lowest total fertility rate in 2019?
#
# Which country has 98% of their pregnant women receiving prenatal care in 2017?
#
# Which country has the highest prevalence of overweight adults in 2016?
#
# Which country is more likely to have a measles outbreak due to the lowest rate of immunization in 2019?
#
# How much female age at first marriage in Slovenia, in 2018?
#
# # Group 7 & 8
# Which country has the highest rate of mortality by road traffic injury in 2019?
#
# Which country has 67% of their pregnant women receiving prenatal care in 2018?
#
# How much is the prevalence of overweight adults in the United States, in 2016?
#
# Which country is more likely to have TBC due to the lowest rate of immunization in 2019?
#
# Which country has the average age of female at first marriage lower than 20 years old in 2016?
#
# # Group 9 & 10
#
# Which country has the highest rate of mortality by road traffic injury in 2019?
#
# How much is the working age population of Qatar in 2020?
#
# How much is the prevalence of overweight adults in Indonesia, in 2016?
#
# Which country has the highest rate of literacy in 2020?
#
# How much is the average female age at first marriage in Indonesia, in 2017?

# %%
import pandas as pd

# %%
# !wget https://cdn.discordapp.com/attachments/951132539878273095/961101693397921892/HNP_StatsData_2.csv -O HNP_StatsData_2.csv
# Out:
# --2022-04-06 04:23:58--  https://cdn.discordapp.com/attachments/951132539878273095/961101693397921892/HNP_StatsData_2.csv
# Resolving cdn.discordapp.com (cdn.discordapp.com)... 162.159.134.233, 162.159.129.233, 162.159.130.233, ...
# Connecting to cdn.discordapp.com (cdn.discordapp.com)|162.159.134.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61967406 (59M) [text/csv]
# Saving to: ‘HNP_StatsData_2.csv’
#
# HNP_StatsData_2.csv 100%[===================>]  59.10M   222MB/s    in 0.3s
#
# 2022-04-06 04:23:59 (222 MB/s) - ‘HNP_StatsData_2.csv’ saved [61967406/61967406]

# %%
df = pd.read_csv("HNP_StatsData_2.csv")

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1  Adults (ages 15+) and children (0-14 years) li...     SH.HIV.TOTL
# 2  Adults (ages 15+) and children (ages 0-14) new...  SH.HIV.INCD.TL
# 3                  Adults (ages 15+) living with HIV     SH.DYN.AIDS
# 4        Adults (ages 15-49) newly infected with HIV     SH.HIV.INCD
#
#          1960        1961        1962       1963       1964        1965  ...  \
# 0  140.120535  140.594564  141.128109  141.32344  141.50816  141.668896  ...
# 1         NaN         NaN         NaN        NaN        NaN         NaN  ...
# ...

# %%
df.info()

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  3.775300e+04  3.830500e+04  3.888000e+04  3.844000e+04  3.849000e+04
# mean   4.540045e+06  4.533358e+06  4.544542e+06  4.695745e+06  4.789000e+06
# std    5.203548e+07  5.222261e+07  5.269100e+07  5.411997e+07  5.522562e+07
# min    0.000000e+00 -2.498824e+00 -3.990892e+06 -3.206682e+00 -3.078607e+00
# 25%    1.567225e+01  1.337077e+01  1.193098e+01  1.374637e+01  1.376329e+01
# 50%    3.634000e+03  3.099000e+03  2.726500e+03  3.171500e+03  3.248000e+03
# 75%    8.957300e+04  8.858600e+04  8.774700e+04  9.156875e+04  9.295000e+04
# max    3.032156e+09  3.071596e+09  3.124561e+09  3.189656e+09  3.255146e+09
#
#                1965          1966          1967          1968          1969  \
# count  3.865100e+04  3.859500e+04  3.911900e+04  3.870900e+04  3.879200e+04
# mean   4.870422e+06  4.984342e+06  5.022137e+06  5.184691e+06  5.286047e+06
# ...

# %%
df['Country Name'].value_counts()
# Out:
# Africa Eastern and Southern    441
# Morocco                        441
# Malawi                         441
# Malaysia                       441
# Maldives                       441
#                               ...
# Congo, Rep.                    441
# Costa Rica                     441
# Cote d'Ivoire                  441
# Croatia                        441
# Zimbabwe                       441
# Name: Country Name, Length: 266, dtype: int64

# %%
df['Indicator Name'].unique()
# Out:
# array(['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Adults (ages 15+) and children (0-14 years) living with HIV',
#        'Adults (ages 15+) and children (ages 0-14) newly infected with HIV',
#        'Adults (ages 15+) living with HIV',
#        'Adults (ages 15-49) newly infected with HIV',
#        'Age at first marriage, female', 'Age at first marriage, male',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old', 'Age dependency ratio, young',
#        'Age population, age 00, female, interpolated',
#        'Age population, age 00, male, interpolated',
#        'Age population, age 01, female, interpolated',
#        'Age population, age 01, male, interpolated',
#        'Age population, age 02, female, interpolated',
#        'Age population, age 02, male, interpolated',
#        'Age population, age 03, female, interpolated',
#        'Age population, age 03, male, interpolated',
# ...

# %% [markdown]
# # Group 4 Nomor 1

# %% [markdown]
# [link](https://docs.google.com/document/d/1ESGAs-Wpm09spp-fq2w4ggAkvDvNHhbM51dFwBotsig/edit)

# %%
country_fertility = df[['Country Name','Indicator Name', '2019']]
country_fertility.loc[country_fertility['Indicator Name'] == 'Fertility rate, total (births per woman)'].sort_values('2019', ascending=False)
country_fertility
# Out:
#                      Country Name                            Indicator Name  \
# 84791                       Niger  Fertility rate, total (births per woman)
# 99344                     Somalia  Fertility rate, total (births per woman)
# 41132            Congo, Dem. Rep.  Fertility rate, total (births per woman)
# 75530                        Mali  Fertility rate, total (births per woman)
# 38486                        Chad  Fertility rate, total (births per woman)
# ...                           ...                                       ...
# 94052                  San Marino  Fertility rate, total (births per woman)
# 97580   Sint Maarten (Dutch part)  Fertility rate, total (births per woman)
# 101549        St. Kitts and Nevis  Fertility rate, total (births per woman)
# 109928   Turks and Caicos Islands  Fertility rate, total (births per woman)
# 110369                     Tuvalu  Fertility rate, total (births per woman)
#
#          2019
# 84791   6.824
# 99344   5.978
# ...

# %%
# country_fertility2 = df.groupby(['Country Name','Indicator Name'])['2019'].sum().sort_values(ascending=False)
# # country_fertility2 = country_fertility2.loc[country_fertility2['Indicator Name'] == 'Fertility rate, total (births per woman)'].sort_values( ascending=False)
# country_fertility2

# %% [markdown]
# # Nomor 2

# %%
diabetes = df[['Country Name','Indicator Name', '2021']]
diabetes = diabetes.loc[diabetes['Indicator Name'] == 'Diabetes prevalence (% of population ages 20 to 79)'].sort_values('2021')
diabetes
# Out:
#                      Country Name  \
# 30531                       Benin
# 53022                 Gambia, The
# 116967                   Zimbabwe
# 57432                      Guinea
# 57873               Guinea-Bissau
# ...                           ...
# 54786                   Gibraltar
# 68016                      Kosovo
# 97563   Sint Maarten (Dutch part)
# 102414   St. Martin (French part)
# 109911   Turks and Caicos Islands
#
#                                            Indicator Name  2021
# 30531   Diabetes prevalence (% of population ages 20 t...   1.1
# 53022   Diabetes prevalence (% of population ages 20 t...   1.9
# 116967  Diabetes prevalence (% of population ages 20 t...   2.1
# 57432   Diabetes prevalence (% of population ages 20 t...   2.1
# 57873   Diabetes prevalence (% of population ages 20 t...   2.1
# ...                                                   ...   ...
# 54786   Diabetes prevalence (% of population ages 20 t...   NaN
# ...

# %% [markdown]
# # Nomor 3

# %%
indonesia = df[['Country Name','Indicator Name', '2016']]
indonesia = overweight.loc[overweight['Indicator Name'] == 'Prevalence of overweight (% of adults)'].sort_values('2016')
overweight
# Out:
#                     Country Name                          Indicator Name  \
# 115005                   Vietnam  Prevalence of overweight (% of adults)
# 61203                      India  Prevalence of overweight (% of adults)
# 28569                 Bangladesh  Prevalence of overweight (% of adults)
# 19308    South Asia (IDA & IBRD)  Prevalence of overweight (% of adults)
# 18867                 South Asia  Prevalence of overweight (% of adults)
# ...                          ...                                     ...
# 102657  St. Martin (French part)  Prevalence of overweight (% of adults)
# 103539                     Sudan  Prevalence of overweight (% of adults)
# 110154  Turks and Caicos Islands  Prevalence of overweight (% of adults)
# 115446     Virgin Islands (U.S.)  Prevalence of overweight (% of adults)
# 115887        West Bank and Gaza  Prevalence of overweight (% of adults)
#
#              2016
# 115005  18.300000
# 61203   19.700000
# 28569   20.000000
# ...

# %% [markdown]
# # Nomor 4

# %%
indonesia = df[['Country Name','Indicator Name', '2020']]
indonesia = indonesia.loc[indonesia['Indicator Name'] == 'Children (0-14) living with HIV']
indonesia = indonesia.loc[indonesia['Country Name'] == 'Indonesia'].sort_values('2020')
indonesia
# Out:
#       Country Name                   Indicator Name     2020
# 61371    Indonesia  Children (0-14) living with HIV  18000.0

# %% [markdown]
# # Nomor 5

# %%
dying = df[['Country Name','Indicator Name', '2020']]
dying = dying.loc[dying['Indicator Name'] == 'Probability of dying among children ages 5-9 years (per 1,000)'].sort_values('2020', ascending=False)
dying
# Out:
#                      Country Name  \
# 99598                     Somalia
# 96952                Sierra Leone
# 85045                       Niger
# 38299    Central African Republic
# 85486                     Nigeria
# ...                           ...
# 91660                 Puerto Rico
# 97834   Sint Maarten (Dutch part)
# 102685   St. Martin (French part)
# 110182   Turks and Caicos Islands
# 115474      Virgin Islands (U.S.)
#
#                                            Indicator Name  2020
# 99598   Probability of dying among children ages 5-9 y...  16.1
# 96952   Probability of dying among children ages 5-9 y...  15.9
# 85045   Probability of dying among children ages 5-9 y...  15.7
# 38299   Probability of dying among children ages 5-9 y...  15.7
# 85486   Probability of dying among children ages 5-9 y...  14.1
# ...                                                   ...   ...
# 91660   Probability of dying among children ages 5-9 y...   NaN
# ...

# %% [markdown]
# Answer #https://wandakinasih.my.canva.site/np95mnbv1sktnp3dn6sma122a2
